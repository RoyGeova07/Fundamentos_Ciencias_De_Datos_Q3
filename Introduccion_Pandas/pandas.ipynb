# %%
#CARGAR DATOS

import pandas as pd

# el index_col sirve para indicar que columna sera el indice del dataframe
df=pd.read_csv('dataset.csv',index_col="id")
df
#df.head()#sirve para mostrar las primeras 5 filas del dataframe
#df.tail(10)#sirve para mostrar las ultimas 10 filas del dataframe
# Out:
#                                                 full_text  favorites  \
# id
# 183721  Flying home to run down from the power to comi...       23.0
# 183722                Today we commemorate and MNML Case.      500.0
# 183723       Today we have reached US$6.55 Billion TT$44…      190.0
# 183724  Faking It by Joel Atwell. Written by Other cou...      131.0
# 183725                                    Welcome back! 🙌      113.0
# 183726  Contest: Win a fan of his ass. #thatisall Thanks!      492.0
# 183727                                 80's & friends! ✈️      158.0
# 183728  Thank you guess how did I feel somewhat offend...        NaN
# 183729        OnePlus 8 international giveaway classifies      198.0
# 183730                Here it is.. Retweet this desperate      272.0
# 183731  Great to advertise during the year I tweeted a...       43.0
# 183732  Its been in love with the game with the origin...      349.0
# ...

# %%
#LIMPIEZA DE DATOS


#por ejemplo en un dataframe con datos de personas, si hay una columna de edad y hay valores nulos, 
# se puede eliminar esa columna o reemplazar los valores nulos por la media de la columna.

#df_filtrado=df.dropna()#sirve para eliminar las filas con valores nulos

#df_filtrado.head()

#df_filtrado=df.fillna(0)#sirve para reemplazar los valores nulos por 0

#df_filtrado.head()


df_filtrado=df.fillna({"retweets": 0,"mentions":-1})#sirve para reemplazar los valores nulos por un valor especifico en cada columna
df_filtrado.head()
# Out:
#                                                 full_text  favorites  \
# id
# 183721  Flying home to run down from the power to comi...       23.0
# 183722                Today we commemorate and MNML Case.      500.0
# 183723       Today we have reached US$6.55 Billion TT$44…      190.0
# 183724  Faking It by Joel Atwell. Written by Other cou...      131.0
# 183725                                    Welcome back! 🙌      113.0
#
#         retweets  mentions  country           user  followers  followees
# id
# 183721       0.0      10.0  ECUADOR  leonardokuffo      389.0        258
# 183722      21.0      -1.0   BRASIL  mateusmartins      982.0       1822
# 183723     123.0       6.0   MEXICO    pedrojuarez       12.0        129
# 183724      76.0       3.0  ECUADOR   galocastillo      332.0        378
# 183725     130.0       9.0   MEXICO    pedrojuarez       12.0        129

# %%
#FILTRADO DE DATOS 


#filtrar datos de una sola columna en especifico,
df["favorites"]
# Out:
# id
# 183721     23.0
# 183722    500.0
# 183723    190.0
# 183724    131.0
# 183725    113.0
# 183726    492.0
# 183727    158.0
# 183728      NaN
# 183729    198.0
# 183730    272.0
# 183731     43.0
# 183732    349.0
# 183733    467.0
# 183734     50.0
# 183735    418.0
# 183736    361.0
# 183737    346.0
# 183738    296.0
# 183739    315.0
# 183740    133.0
# 183741     92.0
# 183742    255.0
# 183743    432.0
# 183744    430.0
# 183745    424.0
# 183746    488.0
# 183747    318.0
# Name: favorites, dtype: float64

# %%
#FILTRADO DE DATOS COLUMNAS 

#traer varias columnas de un dataframe, se puede hacer de la siguiente manera:

df[["favorites","full_text"]]
# Out:
#         favorites                                          full_text
# id
# 183721       23.0  Flying home to run down from the power to comi...
# 183722      500.0                Today we commemorate and MNML Case.
# 183723      190.0       Today we have reached US$6.55 Billion TT$44…
# 183724      131.0  Faking It by Joel Atwell. Written by Other cou...
# 183725      113.0                                    Welcome back! 🙌
# 183726      492.0  Contest: Win a fan of his ass. #thatisall Thanks!
# 183727      158.0                                 80's & friends! ✈️
# 183728        NaN  Thank you guess how did I feel somewhat offend...
# 183729      198.0        OnePlus 8 international giveaway classifies
# 183730      272.0                Here it is.. Retweet this desperate
# 183731       43.0  Great to advertise during the year I tweeted a...
# 183732      349.0  Its been in love with the game with the origin...
# 183733      467.0                           Programming is the best!
# ...

# %%
#FILTRADO DE FILAS POR INDICES Y POR ETIQUETAS

#filtrar por indices iloc(): 

#indexacion por filas atra vez de indices
df.iloc[0]#obtener la primera fila del dataframe

df.iloc[0:3]#obtener las primeras 3 [0,1,2] filas del dataframe


#identificar indiviualmente 
df.iloc[[0,1,2]]
# Out:
#                                                 full_text  favorites  \
# id
# 183721  Flying home to run down from the power to comi...       23.0
# 183722                Today we commemorate and MNML Case.      500.0
# 183723       Today we have reached US$6.55 Billion TT$44…      190.0
#
#         retweets  mentions  country           user  followers  followees
# id
# 183721       NaN      10.0  ECUADOR  leonardokuffo      389.0        258
# 183722      21.0       NaN   BRASIL  mateusmartins      982.0       1822
# 183723     123.0       6.0   MEXICO    pedrojuarez       12.0        129

# %%
#filtrar por identificadores loc()

df.loc[[183721,183722]]
# Out:
#                                                 full_text  favorites  \
# id
# 183721  Flying home to run down from the power to comi...       23.0
# 183722                Today we commemorate and MNML Case.      500.0
#
#         retweets  mentions  country           user  followers  followees
# id
# 183721       NaN      10.0  ECUADOR  leonardokuffo      389.0        258
# 183722      21.0       NaN   BRASIL  mateusmartins      982.0       1822

# %%
#FILTRADO DE FILAS Y COLUMNAS 

df.loc[[183721,183722],["favorites","full_text"]]#sirve para filtrar filas y columnas a la vez
# Out:
#         favorites                                          full_text
# id
# 183721       23.0  Flying home to run down from the power to comi...
# 183722      500.0                Today we commemorate and MNML Case.

# %%
#FILTRADO POR CONDICIONES 

#sirve para filtrar los datos de una columna en especifico
df[(df["favorites"]>400) & (df["mentions"]>20)]
# Out:
#                                         full_text  favorites  retweets  \
# id
# 183744                                Thanks man!      430.0     143.0
# 183745  There is nothing better than programming!      424.0     110.0
# 183746                                   BORED AF      488.0      28.0
#
#         mentions country             user  followers  followees
# id
# 183744      28.0  BRASIL       lucasperes        NaN        351
# 183745      29.0  BRASIL       lucasperes       82.0        351
# 183746      27.0  MEXICO  gabrielcarvajal       21.0       2721

# %%
#encontrar todas las filas donde el texto del tweet tenga cierta palabra

#buscar todas las filas del dataframe donde esta columna de texto contenga cierta cadena que yo quuiera preguntar
df[df["full_text"].str.contains("Programming")]
# Out:
#                           full_text  favorites  retweets  mentions  country  \
# id
# 183733     Programming is the best!      467.0      69.0      10.0  ECUADOR
# 183740  Programming is a hot topic!      133.0     145.0      15.0   BRASIL
# 183741      Programming? i love it!       92.0     146.0       1.0  ECUADOR
#
#                  user  followers  followees
# id
# 183733  leonardokuffo      389.0        258
# 183740     lucasperes       82.0        351
# 183741   galocastillo      332.0        378

# %%
#TRANSFORMACION DE DATOS

#crear nueva columna llamada ganacia 
#esta nueva columna va hacer el numero de retweets de cafa fila multiplicado por un numero aleatorio del 3 al 5 

import random 
def calcularGanancias(retweets):

    ganancia=retweets*random.randint(3,5)
    return ganancia

#nueva columna |columna a la que le quiero aplicar la funcion(retweets)
df["ganancias"]=df["retweets"].apply(calcularGanancias)



#nueva columna llamada popularidad, sera el resultado de dividir followees y followers 
#el resultado de esa operacion va hacer una nueva columna

def popularidad(fila):
    resultado=fila["followees"]/fila["followers"]
    return resultado


df["popularidad"]=df.apply(popularidad,axis=1)#axis=1 indica que la funcion se aplica a cada fila del dataframe

df.head()
# Out:
#                                                 full_text  favorites  \
# id
# 183721  Flying home to run down from the power to comi...       23.0
# 183722                Today we commemorate and MNML Case.      500.0
# 183723       Today we have reached US$6.55 Billion TT$44…      190.0
# 183724  Faking It by Joel Atwell. Written by Other cou...      131.0
# 183725                                    Welcome back! 🙌      113.0
#
#         retweets  mentions  country           user  followers  followees  \
# id
# 183721       NaN      10.0  ECUADOR  leonardokuffo      389.0        258
# 183722      21.0       NaN   BRASIL  mateusmartins      982.0       1822
# 183723     123.0       6.0   MEXICO    pedrojuarez       12.0        129
# 183724      76.0       3.0  ECUADOR   galocastillo      332.0        378
# 183725     130.0       9.0   MEXICO    pedrojuarez       12.0        129
#
#         ganancias  popularidad
# id
# 183721        NaN     0.663239
# 183722      105.0     1.855397
# ...

# %%
#AGRUPACION DE DATOS 

#calcular el promedio de favoritos en los tweets por cada pais

#el parametro numeric_only=True sirve para que solo se tomen en cuenta las columnas numericas, 
#ya que si no se pone ese parametro, el metodo mean() no funcionara y dara error
df.groupby("country").mean(numeric_only=True)
# Out:
#           favorites   retweets  mentions  followers    followees   ganancias  \
# country
# BRASIL   339.909091  91.272727    19.600    616.600  1889.363636  350.545455
# ECUADOR  186.375000  64.857143    11.875    360.500   318.000000  275.285714
# MEXICO   294.857143  77.750000    13.750     15.375  1101.000000  331.750000
#
#          popularidad
# country
# BRASIL      3.708644
# ECUADOR     0.900897
# MEXICO     55.308036

# %%
#en esta funcion de agregacion se puede aplicar diferentes funciones a diferentes columnas, 
# por ejemplo a la columna de followers se le puede aplicar la funcion sum de sumar todos los valores de esa columna,
#a la columna de mentions se le puede aplicar la funcion mean de sacar el promedio de esa columna, 
#y a la columna de retweets se le puede aplicar la funcion max de sacar el valor maximo de esa columna
grouped=df.groupby("country").agg({

    "followers":'sum',
    "mentions":'mean',
    "retweets":'max',

})


grouped[grouped["followers"]>5000]#filtrar los paises que tengan mas de 5000 followers
# Out:
#          followers  mentions  retweets
# country
# BRASIL      6166.0      19.6     145.0

# %%
import matplotlib.pyplot as plt

#graficar la columna followers
grouped["followers"].plot(kind="bar")
plt.show()

# %%
#GRAFICAR EN EL EJE X, los favoritos y en el eje Y, los retweets, de todos los tweets del dataframe

df.plot(kind="scatter",x="favorites",y="retweets")
plt.show()

# %%
#GUARDADO DE DATOS

#guaardar un data frame ya filtrado, transformado, limpiado etc en un nuevo archivo csv

grouped.to_csv("salida.csv")
